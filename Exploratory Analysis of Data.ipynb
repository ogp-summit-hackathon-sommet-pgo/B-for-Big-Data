# %%
import pandas as pd

df = pd.read_csv("datasets/toronto/bike_parking_map_data.csv")

print(df)
# Out:
#       _id  ADDRESS_POINT_ID ADDRESS_NUMBER   LINEAR_NAME_FULL  \
# 0    9361           7641979             21       Gerrard St E
# 1    9362          13991178            213       Delaware Ave
# 2    9363          13991178            213       Delaware Ave
# 3    9364          14206623           2198           Yonge St
# 4    9365          10494377            222        Spadina Ave
# 5    9366            765142            236        Augusta Ave
# 6    9367          30035743             36          Lisgar St
# 7    9368          10223676            468          King St W
# 8    9369          14211049              5          Walmer Rd
# 9    9370          10223683            500          King St W
# 10   9371          13991066            584         Bloor St W
# 11   9372           8416837            692         Bloor St W
# 12   9373           7792587            790             Bay St
# 13   9374            880972            241    Wellington St W
# ...
