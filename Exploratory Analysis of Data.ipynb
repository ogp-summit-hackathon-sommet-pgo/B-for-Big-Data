# %%
import pandas as pd

df_bike_parking = pd.read_csv("datasets/toronto/bike_parking_map_data.csv")
df_neighbourhoods = pd.read_csv("datasets/toronto/neighbourhoods_map_data.csv")

print(df_neighbourhoods)
# Out:
#       _id   AREA_ID  AREA_ATTR_ID  PARENT_AREA_ID  AREA_SHORT_CODE  \
# 0    1261  25886861      25926662           49885               94
# 1    1262  25886820      25926663           49885              100
# 2    1263  25886834      25926664           49885               97
# 3    1264  25886593      25926665           49885               27
# 4    1265  25886688      25926666           49885               31
# 5    1266  25886404      25926667           49885              114
# 6    1267  25886627      25926668           49885               38
# 7    1268  25886808      25926669           49885              105
# 8    1269  25886812      25926670           49885              103
# 9    1270  25886328      25926671           49885               56
# 10   1271  25886972      25926672           49885               84
# 11   1272  25886804      25926673           49885               19
# 12   1273  25886422      25926674           49885              132
# ...

# %%
import json

def process_geo_data(df):
    print( df["geometry"] )

process_geo_data(df_bike_parking)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7d4697edb1e1> in <module>()
#       4     print( json.loads(df["geometry"]) )
#       5
# ----> 6 process_geo_data(df_bike_parking)
#
# <ipython-input-14-7d4697edb1e1> in process_geo_data(df)
#       2
#       3 def process_geo_data(df):
# ----> 4     print( json.loads(df["geometry"]) )
#       5
#       6 process_geo_data(df_bike_parking)
#
# C:\Users\Owner\Documents\Anaconda\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# ...
